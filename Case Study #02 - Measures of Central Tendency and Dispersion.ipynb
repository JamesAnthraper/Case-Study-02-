# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv(r"D:\James\DSA\StudentsPerformance.csv")
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %% [markdown]
# # 1.

# %%
data.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
 data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data["gender"].value_counts('math score'!='NaN')
# Out:
# female    0.518
# male      0.482
# Name: gender, dtype: float64

# %%
plt.figure(figsize=(4,4))
sns.countplot(data['gender'])
plt.title("Gender wise participation in the test")
# Out:
# Text(0.5, 1.0, 'Gender wise participation in the test')

# %% [markdown]
# ##### Answer: There are 518 Females and 482 Males who have participated in the test

# %% [markdown]
# # 2.

# %%
data["parental level of education"].tolist()
# Out:
# ['some high school',
#  'high school',
#  'some high school',
#  'some college',
#  'some college',
#  'high school',
#  'some high school',
#  "associate's degree",
#  'some high school',
#  'high school',
#  'some high school',
#  "bachelor's degree",
#  'some high school',
#  'some college',
#  'some high school',
#  'high school',
#  'high school',
#  'high school',
#  'high school',
#  'some college',
#  'high school',
#  'some high school',
#  'high school',
#  "associate's degree",
#  'some high school',
#  "bachelor's degree",
#  'some high school',
#  'high school',
#  'some high school',
#  "associate's degree",
#  'high school',
#  "associate's degree",
#  "master's degree",
#  "associate's degree",
#  "master's degree",
#  'some high school',
#  "associate's degree",
#  'some high school',
#  'high school',
#  'high school',
#  'high school',
#  'high school',
#  'some college',
#  "associate's degree",
#  'some college',
#  "bachelor's degree",
#  'some high school',
# ...

# %%
plt.figure(figsize=(10, 4))
sns.countplot(x='parental level of education', data=data)
plt.title("Parental Level of Education")
# Out:
# Text(0.5, 1.0, 'Parental Level of Education')

# %%
data['parental level of education'].unique()
# Out:
# array(['some high school', 'high school', 'some college',
#        "associate's degree", "bachelor's degree", "master's degree"],
#       dtype=object)

# %% [markdown]
# ##### Answer: The highest level of the students' parental level of education is Master's Degree and the lowest level is some high school. Most of the parents have some college level of education

# %% [markdown]
# # 3.

# %% [markdown]
# ### A.

# %%
data.groupby('gender')['math score'].mean()
# Out:
# gender
# female    63.376448
# male      68.821577
# Name: math score, dtype: float64

# %%
data.groupby('gender')['reading score'].mean()
# Out:
# gender
# female    72.590734
# male      65.545643
# Name: reading score, dtype: float64

# %%
data.groupby('gender')['writing score'].mean()
# Out:
# gender
# female    72.467181
# male      63.446058
# Name: writing score, dtype: float64

# %%
s=

# %% [markdown]
# #### Answer: In math score male score is more but in reading score and writing score female score is more than male

# %% [markdown]
# ### B.

# %%
 data.groupby('test preparation course')['math score'].mean()
# Out:
# test preparation course
# completed    69.96648
# none         63.78972
# Name: math score, dtype: float64

# %%
data.groupby('test preparation course')['reading score'].mean()
# Out:
# test preparation course
# completed    74.175978
# none         66.417445
# Name: reading score, dtype: float64

# %%
data.groupby('test preparation course')['writing score'].mean()
# Out:
# test preparation course
# completed    74.684358
# none         64.457944
# Name: writing score, dtype: float64

# %% [markdown]
# #### Answer: The persons who have completed the test preparation course have scored more in all three subject

# %% [markdown]
# # 4.

# %% [markdown]
# ### A.

# %%
data.groupby('gender')['math score'].var()
# Out:
# gender
# female    256.958593
# male      211.889097
# Name: math score, dtype: float64

# %%
data.groupby('gender')['reading score'].var()
# Out:
# gender
# female    207.677438
# male      200.211010
# Name: reading score, dtype: float64

# %%
data.groupby('gender')['writing score'].var()
# Out:
# gender
# female    220.369327
# male      202.413924
# Name: writing score, dtype: float64

# %% [markdown]
# #### Answer: Female have the more scoring variation for math, reading and writing scores

# %% [markdown]
# ### B.

# %%
data.groupby('test preparation course')['math score'].var()
# Out:
# test preparation course
# completed    210.884027
# none         246.668662
# Name: math score, dtype: float64

# %%
data.groupby('test preparation course')['reading score'].var()
# Out:
# test preparation course
# completed    183.265864
# none         213.419851
# Name: reading score, dtype: float64

# %%
data.groupby('test preparation course')['writing score'].var()
# Out:
# test preparation course
# completed    175.202612
# none         226.251739
# Name: writing score, dtype: float64

# %% [markdown]
# #### Answer: The persons who have not completed the test preparation course have the more scoring variation for math, reading and writing scores

# %% [markdown]
# # 5.

# %%
Top=data.sort_values("math score",ascending=False)
s=Top.shape
p=s[0]
t=p*25/100
print('Number of top 25% students is', t)
# Out:
# Number of top 25% students is 250.0

# %%
Top.head(250)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 856    male        group E            some high school      standard
# 855    male        group E          associate's degree  free/reduced
# 854    male        group D            some high school      standard
# 853    male        group D          associate's degree  free/reduced
# 852    male        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# #### Answer: There are 250 students in top 25%
